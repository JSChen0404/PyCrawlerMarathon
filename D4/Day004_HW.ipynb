# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"20103237405","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","display_login":"LombiqBot","gravatar_id":"","url":"https://api.github.com/users/LombiqBot","avatar_url":"https://avatars.githubusercontent.com/u/8517910?"},"repo":{"id":86929735,"name":"Lombiq/Orchard","url":"https://api.github.com/repos/Lombiq/Orchard"},"payload":{"push_id":9027667884,"size":0,"distinct_size":0,"ref":"refs/heads/fix/GetPhysicalPath_Querystring_Support","head":"2279e66f43f223f666cb1ae5f609d068e9b9e854","before":"2279e66f43f223f666cb1ae5f609d068e9b9e854","commits":[]},"public":true,"created_at":"2022-02-07T07:50:36Z","org":{"id":8158177,"login":"Lombiq","gravatar_id":"","url":"https://api.github.com/orgs/Lombiq","avatar_url":"https://avatars.githubusercontent.com/u/8158177?"}},{"id":"20103237376","type":"PushEvent","actor":{"id":29418825,"login":"lisztkao","display_login":"lisztkao","gravatar_id":"","url":"https://api.github.com/users/lisztkao","avatar_url":"https://avatars.githubusercontent.com/u/29418825?"},"repo":{"id":206010086,"name":"lisztkao/build_scripts","url":"https://api.github.com/repos/lisztkao/build_scripts"},"payload":{"push_id":9027667876,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"dd83363f64497394b76ddbea84f68424edfc2e35","before":"3cd3a2cb5ec4b486c559839a8a3d4e349e5b1171","commits":[{"sha":"dd83363f64497394b76ddbea84f68424edfc2e35","author":{"email":"liszt.kao@advantech.com.tw","name":"Liszt.Kao"},"message":"add","distinct":true,"url":"https://api.github.com/repos/lisztkao/build_scripts/commits/dd83363f64497394b76ddbea84f68424edfc2e35"}]},"public":true,"created_at":"2022-02-07T07:50:36Z"},{"id":"20103237372","type":"PushEvent","actor":{"id":65811707,"login":"iamfaiyam","display_login":"iamfaiyam","gravatar_id":"","url":"https://api.github.com/users/iamfaiyam","avatar_url":"https://avatars.githubusercontent.com/u/65811707?"},"repo":{"id":456344771,"name":"iamfaiyam/Python-Projects-2022","url":"https://api.github.com/repos/iamfaiyam/Python-Projects-2022"},"payload":{"push_id":9027667874,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"6063934d9741717e5b4ef8b96caac5c6b16554a9","before":"0f0693cc4dc275eeb8429144910f28b92d00c6de","commits":[{"sha":"6063934d9741717e5b4ef8b96caac5c6b16554a9","author":{"email":"65811707+iamfaiyam@users.noreply.github.com","name":"Faiyam Islam"},"message":"Create README.md","distinct":true,"url":"https://api.github.com/repos/iamfaiyam/Python-Projects-2022/commits/6063934d9741717e5b4ef8b96caac5c6b16554a9"}]},"public":true,"created_at":"2022-02-07T07:50:36Z"},{"id":"20103237362","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":437268278,"name":"jamesmstone/vicemergency","url":"https://api.github.com/repos/jamesmstone/vicemergency"},"payload":{"push_id":9027667865,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"4d90d2ad5fff863dc59e28f6f9d47023bcf18ee9","before":"ac67c75b4a0ae4c5121fa0eef944ef82ebff29d3","commits":[{"sha":"4d90d2ad5fff863dc59e28f6f9d47023bcf18ee9","author":{"email":"actions@users.noreply.github.com","name":"Automated"},"message":"Latest data: Mon Feb  7 07:50:35 UTC 2022","distinct":true,"url":"https://api.github.com/repos/jamesmstone/vicemergency/commits/4d90d2ad5fff863dc59e28f6f9d47023bcf18ee9"}]},"public":true,"created_at":"2022-02-07T07:50:36Z"},{"id":"20103237346","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":401407048,"name":"louisefindlay23/section-author-feed","url":"https://api.github.com/repos/louisefindlay23/section-author-feed"},"payload":{"push_id":9027667857,"size":1,"distinct_size":1,"ref":"refs/heads/master" ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '20103237405',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 9027667884,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/fix/GetPhysicalPath_Querystring_Support',
#    'head': '2279e66f43f223f666cb1ae5f609d068e9b9e854',
#    'before': '2279e66f43f223f666cb1ae5f609d068e9b9e854',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '20103237376',
#   'type': 'PushEvent',
#   'actor': {'id': 29418825,
#    'login': 'lisztkao',
#    'display_login': 'lisztkao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lisztkao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29418825?'},
#   'repo': {'id': 206010086,
#    'name': 'lisztkao/build_scripts',
#    'url': 'https://api.github.com/repos/lisztkao/build_scripts'},
#   'payload': {'push_id': 9027667876,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dd83363f64497394b76ddbea84f68424edfc2e35',
#    'before': '3cd3a2cb5ec4b486c559839a8a3d4e349e5b1171',
#    'commits': [{'sha': 'dd83363f64497394b76ddbea84f68424edfc2e35',
#      'author': {'email': 'liszt.kao@advantech.com.tw', 'name': 'Liszt.Kao'},
#      'message': 'add',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lisztkao/build_scripts/commits/dd83363f64497394b76ddbea84f68424edfc2e35'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237372',
#   'type': 'PushEvent',
#   'actor': {'id': 65811707,
#    'login': 'iamfaiyam',
#    'display_login': 'iamfaiyam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iamfaiyam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65811707?'},
#   'repo': {'id': 456344771,
#    'name': 'iamfaiyam/Python-Projects-2022',
#    'url': 'https://api.github.com/repos/iamfaiyam/Python-Projects-2022'},
#   'payload': {'push_id': 9027667874,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6063934d9741717e5b4ef8b96caac5c6b16554a9',
#    'before': '0f0693cc4dc275eeb8429144910f28b92d00c6de',
#    'commits': [{'sha': '6063934d9741717e5b4ef8b96caac5c6b16554a9',
#      'author': {'email': '65811707+iamfaiyam@users.noreply.github.com',
#       'name': 'Faiyam Islam'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/iamfaiyam/Python-Projects-2022/commits/6063934d9741717e5b4ef8b96caac5c6b16554a9'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237362',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 437268278,
#    'name': 'jamesmstone/vicemergency',
#    'url': 'https://api.github.com/repos/jamesmstone/vicemergency'},
#   'payload': {'push_id': 9027667865,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4d90d2ad5fff863dc59e28f6f9d47023bcf18ee9',
#    'before': 'ac67c75b4a0ae4c5121fa0eef944ef82ebff29d3',
#    'commits': [{'sha': '4d90d2ad5fff863dc59e28f6f9d47023bcf18ee9',
#      'author': {'email': 'actions@users.noreply.github.com',
#       'name': 'Automated'},
#      'message': 'Latest data: Mon Feb  7 07:50:35 UTC 2022',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jamesmstone/vicemergency/commits/4d90d2ad5fff863dc59e28f6f9d47023bcf18ee9'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237346',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 401407048,
#    'name': 'louisefindlay23/section-author-feed',
#    'url': 'https://api.github.com/repos/louisefindlay23/section-author-feed'},
#   'payload': {'push_id': 9027667857,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8f9b8898860339587e46e2190743f822051eca0c',
#    'before': 'd878ffa3c2611a149acbbab768fc552abd529a30',
#    'commits': [{'sha': '8f9b8898860339587e46e2190743f822051eca0c',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Updating the README!',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/louisefindlay23/section-author-feed/commits/8f9b8898860339587e46e2190743f822051eca0c'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237378',
#   'type': 'MemberEvent',
#   'actor': {'id': 3605123,
#    'login': 'google-admin',
#    'display_login': 'google-admin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google-admin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3605123?'},
#   'repo': {'id': 456402288,
#    'name': 'GoogleCloudPlatform/dialogflow-cx-bot-language-translation',
#    'url': 'https://api.github.com/repos/GoogleCloudPlatform/dialogflow-cx-bot-language-translation'},
#   'payload': {'member': {'login': 'hwkam',
#     'id': 32817820,
#     'node_id': 'MDQ6VXNlcjMyODE3ODIw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/32817820?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/hwkam',
#     'html_url': 'https://github.com/hwkam',
#     'followers_url': 'https://api.github.com/users/hwkam/followers',
#     'following_url': 'https://api.github.com/users/hwkam/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/hwkam/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/hwkam/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/hwkam/subscriptions',
#     'organizations_url': 'https://api.github.com/users/hwkam/orgs',
#     'repos_url': 'https://api.github.com/users/hwkam/repos',
#     'events_url': 'https://api.github.com/users/hwkam/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/hwkam/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z',
#   'org': {'id': 2810941,
#    'login': 'GoogleCloudPlatform',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GoogleCloudPlatform',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2810941?'}},
#  {'id': '20103237349',
#   'type': 'ForkEvent',
#   'actor': {'id': 98550586,
#    'login': 'ZlotnikovAndrey',
#    'display_login': 'ZlotnikovAndrey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZlotnikovAndrey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98550586?'},
#   'repo': {'id': 342222266,
#    'name': 'netology-ds-team/sal-rab-homeworks',
#    'url': 'https://api.github.com/repos/netology-ds-team/sal-rab-homeworks'},
#   'payload': {'forkee': {'id': 456407054,
#     'node_id': 'R_kgDOGzQ4Dg',
#     'name': 'sal-rab-homeworks',
#     'full_name': 'ZlotnikovAndrey/sal-rab-homeworks',
#     'private': False,
#     'owner': {'login': 'ZlotnikovAndrey',
#      'id': 98550586,
#      'node_id': 'U_kgDOBd_DOg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/98550586?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ZlotnikovAndrey',
#      'html_url': 'https://github.com/ZlotnikovAndrey',
#      'followers_url': 'https://api.github.com/users/ZlotnikovAndrey/followers',
#      'following_url': 'https://api.github.com/users/ZlotnikovAndrey/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ZlotnikovAndrey/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ZlotnikovAndrey/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ZlotnikovAndrey/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ZlotnikovAndrey/orgs',
#      'repos_url': 'https://api.github.com/users/ZlotnikovAndrey/repos',
#      'events_url': 'https://api.github.com/users/ZlotnikovAndrey/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ZlotnikovAndrey/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/ZlotnikovAndrey/sal-rab-homeworks',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks',
#     'forks_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/forks',
#     'keys_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/teams',
#     'hooks_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/hooks',
#     'issue_events_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/events',
#     'assignees_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/tags',
#     'blobs_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/languages',
#     'stargazers_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/stargazers',
#     'contributors_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/contributors',
#     'subscribers_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/subscribers',
#     'subscription_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/subscription',
#     'commits_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/merges',
#     'archive_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/downloads',
#     'issues_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/ZlotnikovAndrey/sal-rab-homeworks/deployments',
#     'created_at': '2022-02-07T07:50:36Z',
#     'updated_at': '2022-01-19T12:32:37Z',
#     'pushed_at': '2021-11-16T19:28:32Z',
#     'git_url': 'git://github.com/ZlotnikovAndrey/sal-rab-homeworks.git',
#     'ssh_url': 'git@github.com:ZlotnikovAndrey/sal-rab-homeworks.git',
#     'clone_url': 'https://github.com/ZlotnikovAndrey/sal-rab-homeworks.git',
#     'svn_url': 'https://github.com/ZlotnikovAndrey/sal-rab-homeworks',
#     'homepage': None,
#     'size': 8590,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z',
#   'org': {'id': 83753353,
#    'login': 'netology-ds-team',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/netology-ds-team',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83753353?'}},
#  {'id': '20103237341',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 377732778,
#    'name': '332990758/bot',
#    'url': 'https://api.github.com/repos/332990758/bot'},
#   'payload': {'action': 'closed',
#    'number': 28,
#    'pull_request': {'url': 'https://api.github.com/repos/332990758/bot/pulls/28',
#     'id': 841417813,
#     'node_id': 'PR_kwDOFoO-qs4yJwRV',
#     'html_url': 'https://github.com/332990758/bot/pull/28',
#     'diff_url': 'https://github.com/332990758/bot/pull/28.diff',
#     'patch_url': 'https://github.com/332990758/bot/pull/28.patch',
#     'issue_url': 'https://api.github.com/repos/332990758/bot/issues/28',
#     'number': 28,
#     'state': 'closed',
#     'locked': False,
#     'title': '[pull] main from SuMaiKaDe:main',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See [Commits](/332990758/bot/pull/28/commits) and [Changes](/332990758/bot/pull/28/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#     'created_at': '2022-02-07T07:50:29Z',
#     'updated_at': '2022-02-07T07:50:36Z',
#     'closed_at': '2022-02-07T07:50:35Z',
#     'merged_at': '2022-02-07T07:50:35Z',
#     'merge_commit_sha': '1323a769c956a79eb9fc8f4b7dbfe0794fb3822e',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 3095574583,
#       'node_id': 'MDU6TGFiZWwzMDk1NTc0NTgz',
#       'url': 'https://api.github.com/repos/332990758/bot/labels/:arrow_heading_down:%20pull',
#       'name': ':arrow_heading_down: pull',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/332990758/bot/pulls/28/commits',
#     'review_comments_url': 'https://api.github.com/repos/332990758/bot/pulls/28/comments',
#     'review_comment_url': 'https://api.github.com/repos/332990758/bot/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/332990758/bot/issues/28/comments',
#     'statuses_url': 'https://api.github.com/repos/332990758/bot/statuses/1323a769c956a79eb9fc8f4b7dbfe0794fb3822e',
#     'head': {'label': 'SuMaiKaDe:main',
#      'ref': 'main',
#      'sha': '1323a769c956a79eb9fc8f4b7dbfe0794fb3822e',
#      'user': {'login': 'SuMaiKaDe',
#       'id': 5207528,
#       'node_id': 'MDQ6VXNlcjUyMDc1Mjg=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5207528?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SuMaiKaDe',
#       'html_url': 'https://github.com/SuMaiKaDe',
#       'followers_url': 'https://api.github.com/users/SuMaiKaDe/followers',
#       'following_url': 'https://api.github.com/users/SuMaiKaDe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SuMaiKaDe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SuMaiKaDe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SuMaiKaDe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SuMaiKaDe/orgs',
#       'repos_url': 'https://api.github.com/users/SuMaiKaDe/repos',
#       'events_url': 'https://api.github.com/users/SuMaiKaDe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SuMaiKaDe/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 376258960,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzYyNTg5NjA=',
#       'name': 'bot',
#       'full_name': 'SuMaiKaDe/bot',
#       'private': False,
#       'owner': {'login': 'SuMaiKaDe',
#        'id': 5207528,
#        'node_id': 'MDQ6VXNlcjUyMDc1Mjg=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5207528?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SuMaiKaDe',
#        'html_url': 'https://github.com/SuMaiKaDe',
#        'followers_url': 'https://api.github.com/users/SuMaiKaDe/followers',
#        'following_url': 'https://api.github.com/users/SuMaiKaDe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SuMaiKaDe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SuMaiKaDe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SuMaiKaDe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SuMaiKaDe/orgs',
#        'repos_url': 'https://api.github.com/users/SuMaiKaDe/repos',
#        'events_url': 'https://api.github.com/users/SuMaiKaDe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SuMaiKaDe/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SuMaiKaDe/bot',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/SuMaiKaDe/bot',
#       'forks_url': 'https://api.github.com/repos/SuMaiKaDe/bot/forks',
#       'keys_url': 'https://api.github.com/repos/SuMaiKaDe/bot/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SuMaiKaDe/bot/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SuMaiKaDe/bot/teams',
#       'hooks_url': 'https://api.github.com/repos/SuMaiKaDe/bot/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SuMaiKaDe/bot/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SuMaiKaDe/bot/events',
#       'assignees_url': 'https://api.github.com/repos/SuMaiKaDe/bot/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SuMaiKaDe/bot/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SuMaiKaDe/bot/tags',
#       'blobs_url': 'https://api.github.com/repos/SuMaiKaDe/bot/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SuMaiKaDe/bot/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SuMaiKaDe/bot/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SuMaiKaDe/bot/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SuMaiKaDe/bot/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SuMaiKaDe/bot/languages',
#       'stargazers_url': 'https://api.github.com/repos/SuMaiKaDe/bot/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SuMaiKaDe/bot/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SuMaiKaDe/bot/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SuMaiKaDe/bot/subscription',
#       'commits_url': 'https://api.github.com/repos/SuMaiKaDe/bot/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SuMaiKaDe/bot/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SuMaiKaDe/bot/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SuMaiKaDe/bot/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SuMaiKaDe/bot/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SuMaiKaDe/bot/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SuMaiKaDe/bot/merges',
#       'archive_url': 'https://api.github.com/repos/SuMaiKaDe/bot/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/SuMaiKaDe/bot/downloads',
#       'issues_url': 'https://api.github.com/repos/SuMaiKaDe/bot/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/SuMaiKaDe/bot/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/SuMaiKaDe/bot/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/SuMaiKaDe/bot/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/SuMaiKaDe/bot/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/SuMaiKaDe/bot/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/SuMaiKaDe/bot/deployments',
#       'created_at': '2021-06-12T10:15:24Z',
#       'updated_at': '2022-02-07T04:09:54Z',
#       'pushed_at': '2022-02-07T03:36:34Z',
#       'git_url': 'git://github.com/SuMaiKaDe/bot.git',
#       'ssh_url': 'git@github.com:SuMaiKaDe/bot.git',
#       'clone_url': 'https://github.com/SuMaiKaDe/bot.git',
#       'svn_url': 'https://github.com/SuMaiKaDe/bot',
#       'homepage': None,
#       'size': 277,
#       'stargazers_count': 377,
#       'watchers_count': 377,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 174,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 25,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 174,
#       'open_issues': 25,
#       'watchers': 377,
#       'default_branch': 'main'}},
#     'base': {'label': '332990758:main',
#      'ref': 'main',
#      'sha': '3eabbf05848cab57ec7a48e554b490ce7c4db229',
#      'user': {'login': '332990758',
#       'id': 40876484,
#       'node_id': 'MDQ6VXNlcjQwODc2NDg0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/40876484?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/332990758',
#       'html_url': 'https://github.com/332990758',
#       'followers_url': 'https://api.github.com/users/332990758/followers',
#       'following_url': 'https://api.github.com/users/332990758/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/332990758/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/332990758/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/332990758/subscriptions',
#       'organizations_url': 'https://api.github.com/users/332990758/orgs',
#       'repos_url': 'https://api.github.com/users/332990758/repos',
#       'events_url': 'https://api.github.com/users/332990758/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/332990758/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 377732778,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzc3MzI3Nzg=',
#       'name': 'bot',
#       'full_name': '332990758/bot',
#       'private': False,
#       'owner': {'login': '332990758',
#        'id': 40876484,
#        'node_id': 'MDQ6VXNlcjQwODc2NDg0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/40876484?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/332990758',
#        'html_url': 'https://github.com/332990758',
#        'followers_url': 'https://api.github.com/users/332990758/followers',
#        'following_url': 'https://api.github.com/users/332990758/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/332990758/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/332990758/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/332990758/subscriptions',
#        'organizations_url': 'https://api.github.com/users/332990758/orgs',
#        'repos_url': 'https://api.github.com/users/332990758/repos',
#        'events_url': 'https://api.github.com/users/332990758/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/332990758/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/332990758/bot',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/332990758/bot',
#       'forks_url': 'https://api.github.com/repos/332990758/bot/forks',
#       'keys_url': 'https://api.github.com/repos/332990758/bot/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/332990758/bot/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/332990758/bot/teams',
#       'hooks_url': 'https://api.github.com/repos/332990758/bot/hooks',
#       'issue_events_url': 'https://api.github.com/repos/332990758/bot/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/332990758/bot/events',
#       'assignees_url': 'https://api.github.com/repos/332990758/bot/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/332990758/bot/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/332990758/bot/tags',
#       'blobs_url': 'https://api.github.com/repos/332990758/bot/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/332990758/bot/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/332990758/bot/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/332990758/bot/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/332990758/bot/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/332990758/bot/languages',
#       'stargazers_url': 'https://api.github.com/repos/332990758/bot/stargazers',
#       'contributors_url': 'https://api.github.com/repos/332990758/bot/contributors',
#       'subscribers_url': 'https://api.github.com/repos/332990758/bot/subscribers',
#       'subscription_url': 'https://api.github.com/repos/332990758/bot/subscription',
#       'commits_url': 'https://api.github.com/repos/332990758/bot/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/332990758/bot/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/332990758/bot/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/332990758/bot/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/332990758/bot/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/332990758/bot/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/332990758/bot/merges',
#       'archive_url': 'https://api.github.com/repos/332990758/bot/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/332990758/bot/downloads',
#       'issues_url': 'https://api.github.com/repos/332990758/bot/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/332990758/bot/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/332990758/bot/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/332990758/bot/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/332990758/bot/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/332990758/bot/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/332990758/bot/deployments',
#       'created_at': '2021-06-17T06:48:42Z',
#       'updated_at': '2021-12-02T06:57:51Z',
#       'pushed_at': '2022-02-07T07:50:34Z',
#       'git_url': 'git://github.com/332990758/bot.git',
#       'ssh_url': 'git@github.com:332990758/bot.git',
#       'clone_url': 'https://github.com/332990758/bot.git',
#       'svn_url': 'https://github.com/332990758/bot',
#       'homepage': None,
#       'size': 275,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/332990758/bot/pulls/28'},
#      'html': {'href': 'https://github.com/332990758/bot/pull/28'},
#      'issue': {'href': 'https://api.github.com/repos/332990758/bot/issues/28'},
#      'comments': {'href': 'https://api.github.com/repos/332990758/bot/issues/28/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/332990758/bot/pulls/28/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/332990758/bot/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/332990758/bot/pulls/28/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/332990758/bot/statuses/1323a769c956a79eb9fc8f4b7dbfe0794fb3822e'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 15,
#     'deletions': 11,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237309',
#   'type': 'PushEvent',
#   'actor': {'id': 12963815,
#    'login': 'sebastiangolian',
#    'display_login': 'sebastiangolian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sebastiangolian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12963815?'},
#   'repo': {'id': 423601047,
#    'name': 'sebastiangolian/portable-soft',
#    'url': 'https://api.github.com/repos/sebastiangolian/portable-soft'},
#   'payload': {'push_id': 9027667838,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a52a22c7b8f1593893363ce050483c88602b1594',
#    'before': 'dbf6c7cba271f4643d8e8060000cfe88b928d72c',
#    'commits': [{'sha': 'a52a22c7b8f1593893363ce050483c88602b1594',
#      'author': {'email': 'sebastiangolian@gmail.com',
#       'name': 'Sebastian Golian'},
#      'message': "'update'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sebastiangolian/portable-soft/commits/a52a22c7b8f1593893363ce050483c88602b1594'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237336',
#   'type': 'ForkEvent',
#   'actor': {'id': 3167619,
#    'login': 'tqcenglish',
#    'display_login': 'tqcenglish',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tqcenglish',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3167619?'},
#   'repo': {'id': 121079935,
#    'name': 'xaboy/form-create',
#    'url': 'https://api.github.com/repos/xaboy/form-create'},
#   'payload': {'forkee': {'id': 456407053,
#     'node_id': 'R_kgDOGzQ4DQ',
#     'name': 'form-create',
#     'full_name': 'tqcenglish/form-create',
#     'private': False,
#     'owner': {'login': 'tqcenglish',
#      'id': 3167619,
#      'node_id': 'MDQ6VXNlcjMxNjc2MTk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3167619?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tqcenglish',
#      'html_url': 'https://github.com/tqcenglish',
#      'followers_url': 'https://api.github.com/users/tqcenglish/followers',
#      'following_url': 'https://api.github.com/users/tqcenglish/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tqcenglish/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tqcenglish/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tqcenglish/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tqcenglish/orgs',
#      'repos_url': 'https://api.github.com/users/tqcenglish/repos',
#      'events_url': 'https://api.github.com/users/tqcenglish/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tqcenglish/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/tqcenglish/form-create',
#     'description': ':fire::fire::fire: 强大的动态表单生成器|form-create is a form generation component that can generate dynamic rendering, data collection, verification and submission functions through JSON.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/tqcenglish/form-create',
#     'forks_url': 'https://api.github.com/repos/tqcenglish/form-create/forks',
#     'keys_url': 'https://api.github.com/repos/tqcenglish/form-create/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/tqcenglish/form-create/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/tqcenglish/form-create/teams',
#     'hooks_url': 'https://api.github.com/repos/tqcenglish/form-create/hooks',
#     'issue_events_url': 'https://api.github.com/repos/tqcenglish/form-create/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/tqcenglish/form-create/events',
#     'assignees_url': 'https://api.github.com/repos/tqcenglish/form-create/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/tqcenglish/form-create/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/tqcenglish/form-create/tags',
#     'blobs_url': 'https://api.github.com/repos/tqcenglish/form-create/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/tqcenglish/form-create/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/tqcenglish/form-create/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/tqcenglish/form-create/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/tqcenglish/form-create/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/tqcenglish/form-create/languages',
#     'stargazers_url': 'https://api.github.com/repos/tqcenglish/form-create/stargazers',
#     'contributors_url': 'https://api.github.com/repos/tqcenglish/form-create/contributors',
#     'subscribers_url': 'https://api.github.com/repos/tqcenglish/form-create/subscribers',
#     'subscription_url': 'https://api.github.com/repos/tqcenglish/form-create/subscription',
#     'commits_url': 'https://api.github.com/repos/tqcenglish/form-create/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/tqcenglish/form-create/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/tqcenglish/form-create/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/tqcenglish/form-create/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/tqcenglish/form-create/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/tqcenglish/form-create/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/tqcenglish/form-create/merges',
#     'archive_url': 'https://api.github.com/repos/tqcenglish/form-create/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/tqcenglish/form-create/downloads',
#     'issues_url': 'https://api.github.com/repos/tqcenglish/form-create/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/tqcenglish/form-create/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/tqcenglish/form-create/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/tqcenglish/form-create/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/tqcenglish/form-create/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/tqcenglish/form-create/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/tqcenglish/form-create/deployments',
#     'created_at': '2022-02-07T07:50:35Z',
#     'updated_at': '2022-02-07T06:04:22Z',
#     'pushed_at': '2022-01-16T01:36:22Z',
#     'git_url': 'git://github.com/tqcenglish/form-create.git',
#     'ssh_url': 'git@github.com:tqcenglish/form-create.git',
#     'clone_url': 'https://github.com/tqcenglish/form-create.git',
#     'svn_url': 'https://github.com/tqcenglish/form-create',
#     'homepage': 'http://www.form-create.com/v2/',
#     'size': 14105,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237293',
#   'type': 'PushEvent',
#   'actor': {'id': 75541054,
#    'login': 'NinaKonecna',
#    'display_login': 'NinaKonecna',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NinaKonecna',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75541054?'},
#   'repo': {'id': 397606343,
#    'name': 'NinaKonecna/test',
#    'url': 'https://api.github.com/repos/NinaKonecna/test'},
#   'payload': {'push_id': 9027667841,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '951f8e34e3822a85477eafb1c16358619de2a548',
#    'before': '287052ecdc121682fc1893278fdc55bb3cc4369b',
#    'commits': [{'sha': '951f8e34e3822a85477eafb1c16358619de2a548',
#      'author': {'email': '75541054+NinaKonecna@users.noreply.github.com',
#       'name': 'NinaKonecna'},
#      'message': 'Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NinaKonecna/test/commits/951f8e34e3822a85477eafb1c16358619de2a548'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:36Z'},
#  {'id': '20103237299',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 50673670,
#    'login': 'whitesource-for-github-com[bot]',
#    'display_login': 'whitesource-for-github-com',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/whitesource-for-github-com[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50673670?'},
#   'repo': {'id': 434273516,
#    'name': 'webc-zss2/traefik',
#    'url': 'https://api.github.com/repos/webc-zss2/traefik'},
#   'payload': {'action': 'opened',
#    'number': 91,
#    'pull_request': {'url': 'https://api.github.com/repos/webc-zss2/traefik/pulls/91',
#     'id': 841417876,
#     'node_id': 'PR_kwDOGeJ87M4yJwSU',
#     'html_url': 'https://github.com/webc-zss2/traefik/pull/91',
#     'diff_url': 'https://github.com/webc-zss2/traefik/pull/91.diff',
#     'patch_url': 'https://github.com/webc-zss2/traefik/pull/91.patch',
#     'issue_url': 'https://api.github.com/repos/webc-zss2/traefik/issues/91',
#     'number': 91,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore(deps): update dependency @vue/test-utils to v1.0.0',
#     'user': {'login': 'whitesource-for-github-com[bot]',
#      'id': 50673670,
#      'node_id': 'MDM6Qm90NTA2NzM2NzA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/30796?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D',
#      'html_url': 'https://github.com/apps/whitesource-for-github-com',
#      'followers_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/whitesource-for-github-com%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'This PR contains the following updates:\n\n| Package | Type | Update | Change |\n|---|---|---|---|\n| [@vue/test-utils](https://togithub.com/vuejs/vue-test-utils) | devDependencies | patch | [`1.0.0-beta.29` -> `1.0.0`](https://renovatebot.com/diffs/npm/@vue%2ftest-utils/1.0.0-beta.29/1.0.0) |\n\nBy merging this PR, the below vulnerabilities will be automatically resolved:\n\n|  | Severity           | <a href="#"><img src=\'https://whitesource-resources.whitesourcesoftware.com/cvss3.png\' width=19 height=20></a> CVSS Score       |CVE  |\n|---|---|---|---|\n| ![High](https://whitesource-resources.whitesourcesoftware.com/high_vul_bb.png) |  High | 7.4 | [CVE-2020-8203](https://vuln.whitesourcesoftware.com/vulnerability/CVE-2020-8203) |\n| ![High](https://whitesource-resources.whitesourcesoftware.com/high_vul_bb.png) |  High | 7.2 | [CVE-2021-23337](https://vuln.whitesourcesoftware.com/vulnerability/CVE-2021-23337) |\n| ![Medium](https://whitesource-resources.whitesourcesoftware.com/medium_vul_bb.png) |  Medium | 5.3 | [CVE-2020-28500](https://vuln.whitesourcesoftware.com/vulnerability/CVE-2020-28500) |\n\n---\n\n### Release Notes\n\n<details>\n<summary>vuejs/vue-test-utils</summary>\n\n### [`v1.0.0`](https://togithub.com/vuejs/vue-test-utils/blob/master/packages/test-utils/CHANGELOG.md#&#8203;100-httpsgithubcomvuejsvue-test-utilscomparev100-beta33v100-2020-05-05)\n\n[Compare Source](https://togithub.com/vuejs/vue-test-utils/compare/v1.0.0-beta.33...v1.0.0)\n\n##### Features\n\n-   add support of arbitrary mounting point via attachTo option ([#&#8203;1492](https://togithub.com/vuejs/vue-test-utils/issues/1492)) ([f3d0d3f](https://togithub.com/vuejs/vue-test-utils/commit/f3d0d3f1717fd3cc3e406d3ac3f4ace316967211))\n-   Optionally hide deprecation errors ([#&#8203;1518](https://togithub.com/vuejs/vue-test-utils/issues/1518)) ([7a0b7e0](https://togithub.com/vuejs/vue-test-utils/commit/7a0b7e0c695da901f22df2fea53f6fef5e4dadf7))\n-   return nextTick from setters, fix [#&#8203;1515](https://togithub.com/vuejs/vue-test-utils/issues/1515) ([#&#8203;1517](https://togithub.com/vuejs/vue-test-utils/issues/1517)) ([aa7b76d](https://togithub.com/vuejs/vue-test-utils/commit/aa7b76d5996a24bfaca74989907c0982fdeaa013))\n-   stub out transitions by default ([#&#8203;1411](https://togithub.com/vuejs/vue-test-utils/issues/1411)) ([6f0a41a](https://togithub.com/vuejs/vue-test-utils/commit/6f0a41a8f0b643f2e695c68ead78f4980a2725c7))\n-   **test-utils:** add \'overview\' function ([#&#8203;1491](https://togithub.com/vuejs/vue-test-utils/issues/1491)) ([4b0c5c9](https://togithub.com/vuejs/vue-test-utils/commit/4b0c5c94fb29885bb65e26fea64b8ca64960e301)), closes [#&#8203;1461](https://togithub.com/vuejs/vue-test-utils/issues/1461)\n\n### [`v1.0.0-beta.33`](https://togithub.com/vuejs/vue-test-utils/blob/master/packages/test-utils/CHANGELOG.md#&#8203;100-beta33-httpsgithubcomvuejsvue-test-utilscomparev100-beta32v100-beta33-2020-04-08)\n\n[Compare Source](https://togithub.com/vuejs/vue-test-utils/compare/v1.0.0-beta.32...v1.0.0-beta.33)\n\n##### Bug Fixes\n\n-   **test-utils:** fix cancelable attribute in dom events ([#&#8203;1460](https://togithub.com/vuejs/vue-test-utils/issues/1460)) ([b1a532a](https://togithub.com/vuejs/vue-test-utils/commit/b1a532aa72c71d2f4282f4bc31373cb143e82833))\n\n##### Features\n\n-   support lazy modifier with setValue ([#&#8203;1467](https://togithub.com/vuejs/vue-test-utils/issues/1467)) ([afd7a82](https://togithub.com/vuejs/vue-test-utils/commit/afd7a82426c2e72fca61bf00881574d81dffbf68))\n\n### [`v1.0.0-beta.32`](https://togithub.com/vuejs/vue-test-utils/blob/master/packages/test-utils/CHANGELOG.md#&#8203;100-beta32-httpsgithubcomvuejsvue-test-utilscomparev100-beta31v100-beta32-2020-03-09)\n\n[Compare Source](https://togithub.com/vuejs/vue-test-utils/compare/v1.0.0-beta.31...v1.0.0-beta.32)\n\n##### Bug Fixes\n\n-   **types:** emitted can return undefined ([#&#8203;1431](https://togithub.com/vuejs/vue-test-utils/iss ...
#     'created_at': '2022-02-07T07:50:35Z',
#     'updated_at': '2022-02-07T07:50:35Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
# ...
#      'ref': 'generic-repo-refresher',
#      'sha': 'bd8bbd857dcd9a746ecf7bba3609ecc53e6d3436',
#      'user': {'login': 'stashed',
#       'id': 47427725,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NDI3NzI1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/47427725?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/stashed',
#       'html_url': 'https://github.com/stashed',
#       'followers_url': 'https://api.github.com/users/stashed/followers',
#       'following_url': 'https://api.github.com/users/stashed/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/stashed/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/stashed/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/stashed/subscriptions',
#       'organizations_url': 'https://api.github.com/users/stashed/orgs',
#       'repos_url': 'https://api.github.com/users/stashed/repos',
#       'events_url': 'https://api.github.com/users/stashed/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/stashed/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 188287437,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODgyODc0Mzc=',
#       'name': 'cluster',
#       'full_name': 'stashed/cluster',
#       'private': False,
#       'owner': {'login': 'stashed',
#        'id': 47427725,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NDI3NzI1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/47427725?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/stashed',
#        'html_url': 'https://github.com/stashed',
#        'followers_url': 'https://api.github.com/users/stashed/followers',
#        'following_url': 'https://api.github.com/users/stashed/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/stashed/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/stashed/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/stashed/subscriptions',
#        'organizations_url': 'https://api.github.com/users/stashed/orgs',
#        'repos_url': 'https://api.github.com/users/stashed/repos',
#        'events_url': 'https://api.github.com/users/stashed/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/stashed/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/stashed/cluster',
#       'description': 'Kubernetes cluster backup plugin for Stash by AppsCode',
#       'fork': False,
#       'url': 'https://api.github.com/repos/stashed/cluster',
#       'forks_url': 'https://api.github.com/repos/stashed/cluster/forks',
#       'keys_url': 'https://api.github.com/repos/stashed/cluster/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/stashed/cluster/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/stashed/cluster/teams',
#       'hooks_url': 'https://api.github.com/repos/stashed/cluster/hooks',
#       'issue_events_url': 'https://api.github.com/repos/stashed/cluster/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/stashed/cluster/events',
#       'assignees_url': 'https://api.github.com/repos/stashed/cluster/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/stashed/cluster/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/stashed/cluster/tags',
#       'blobs_url': 'https://api.github.com/repos/stashed/cluster/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/stashed/cluster/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/stashed/cluster/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/stashed/cluster/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/stashed/cluster/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/stashed/cluster/languages',
#       'stargazers_url': 'https://api.github.com/repos/stashed/cluster/stargazers',
#       'contributors_url': 'https://api.github.com/repos/stashed/cluster/contributors',
#       'subscribers_url': 'https://api.github.com/repos/stashed/cluster/subscribers',
#       'subscription_url': 'https://api.github.com/repos/stashed/cluster/subscription',
#       'commits_url': 'https://api.github.com/repos/stashed/cluster/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/stashed/cluster/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/stashed/cluster/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/stashed/cluster/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/stashed/cluster/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/stashed/cluster/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/stashed/cluster/merges',
#       'archive_url': 'https://api.github.com/repos/stashed/cluster/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/stashed/cluster/downloads',
#       'issues_url': 'https://api.github.com/repos/stashed/cluster/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/stashed/cluster/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/stashed/cluster/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/stashed/cluster/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/stashed/cluster/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/stashed/cluster/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/stashed/cluster/deployments',
#       'created_at': '2019-05-23T18:35:04Z',
#       'updated_at': '2021-07-08T08:20:07Z',
#       'pushed_at': '2022-02-07T07:50:24Z',
#       'git_url': 'git://github.com/stashed/cluster.git',
#       'ssh_url': 'git@github.com:stashed/cluster.git',
#       'clone_url': 'https://github.com/stashed/cluster.git',
#       'svn_url': 'https://github.com/stashed/cluster',
#       'homepage': 'https://appscode.com/products/stash',
#       'size': 8272,
#       'stargazers_count': 5,
#       'watchers_count': 5,
#       'language': 'Makefile',
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 5,
#       'default_branch': 'master'}},
#     'base': {'label': 'stashed:master',
#      'ref': 'master',
#      'sha': '0219220a10d8715bcbc4312be01530667ad40393',
#      'user': {'login': 'stashed',
#       'id': 47427725,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NDI3NzI1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/47427725?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/stashed',
#       'html_url': 'https://github.com/stashed',
#       'followers_url': 'https://api.github.com/users/stashed/followers',
#       'following_url': 'https://api.github.com/users/stashed/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/stashed/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/stashed/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/stashed/subscriptions',
#       'organizations_url': 'https://api.github.com/users/stashed/orgs',
#       'repos_url': 'https://api.github.com/users/stashed/repos',
#       'events_url': 'https://api.github.com/users/stashed/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/stashed/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 188287437,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODgyODc0Mzc=',
#       'name': 'cluster',
#       'full_name': 'stashed/cluster',
#       'private': False,
#       'owner': {'login': 'stashed',
#        'id': 47427725,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NDI3NzI1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/47427725?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/stashed',
#        'html_url': 'https://github.com/stashed',
#        'followers_url': 'https://api.github.com/users/stashed/followers',
#        'following_url': 'https://api.github.com/users/stashed/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/stashed/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/stashed/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/stashed/subscriptions',
#        'organizations_url': 'https://api.github.com/users/stashed/orgs',
#        'repos_url': 'https://api.github.com/users/stashed/repos',
#        'events_url': 'https://api.github.com/users/stashed/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/stashed/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/stashed/cluster',
#       'description': 'Kubernetes cluster backup plugin for Stash by AppsCode',
#       'fork': False,
#       'url': 'https://api.github.com/repos/stashed/cluster',
#       'forks_url': 'https://api.github.com/repos/stashed/cluster/forks',
#       'keys_url': 'https://api.github.com/repos/stashed/cluster/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/stashed/cluster/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/stashed/cluster/teams',
#       'hooks_url': 'https://api.github.com/repos/stashed/cluster/hooks',
#       'issue_events_url': 'https://api.github.com/repos/stashed/cluster/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/stashed/cluster/events',
#       'assignees_url': 'https://api.github.com/repos/stashed/cluster/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/stashed/cluster/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/stashed/cluster/tags',
#       'blobs_url': 'https://api.github.com/repos/stashed/cluster/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/stashed/cluster/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/stashed/cluster/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/stashed/cluster/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/stashed/cluster/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/stashed/cluster/languages',
#       'stargazers_url': 'https://api.github.com/repos/stashed/cluster/stargazers',
#       'contributors_url': 'https://api.github.com/repos/stashed/cluster/contributors',
#       'subscribers_url': 'https://api.github.com/repos/stashed/cluster/subscribers',
#       'subscription_url': 'https://api.github.com/repos/stashed/cluster/subscription',
#       'commits_url': 'https://api.github.com/repos/stashed/cluster/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/stashed/cluster/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/stashed/cluster/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/stashed/cluster/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/stashed/cluster/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/stashed/cluster/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/stashed/cluster/merges',
#       'archive_url': 'https://api.github.com/repos/stashed/cluster/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/stashed/cluster/downloads',
#       'issues_url': 'https://api.github.com/repos/stashed/cluster/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/stashed/cluster/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/stashed/cluster/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/stashed/cluster/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/stashed/cluster/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/stashed/cluster/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/stashed/cluster/deployments',
#       'created_at': '2019-05-23T18:35:04Z',
#       'updated_at': '2021-07-08T08:20:07Z',
#       'pushed_at': '2022-02-07T07:50:24Z',
#       'git_url': 'git://github.com/stashed/cluster.git',
#       'ssh_url': 'git@github.com:stashed/cluster.git',
#       'clone_url': 'https://github.com/stashed/cluster.git',
#       'svn_url': 'https://github.com/stashed/cluster',
#       'homepage': 'https://appscode.com/products/stash',
#       'size': 8272,
#       'stargazers_count': 5,
#       'watchers_count': 5,
#       'language': 'Makefile',
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 5,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/stashed/cluster/pulls/9'},
#      'html': {'href': 'https://github.com/stashed/cluster/pull/9'},
#      'issue': {'href': 'https://api.github.com/repos/stashed/cluster/issues/9'},
#      'comments': {'href': 'https://api.github.com/repos/stashed/cluster/issues/9/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/stashed/cluster/pulls/9/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/stashed/cluster/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/stashed/cluster/pulls/9/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/stashed/cluster/statuses/bd8bbd857dcd9a746ecf7bba3609ecc53e6d3436'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-02-07T07:50:35Z',
#   'org': {'id': 47427725,
#    'login': 'stashed',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/stashed',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47427725?'}},
#  {'id': '20103237179',
#   'type': 'PushEvent',
#   'actor': {'id': 33799954,
#    'login': 'islamshalaby',
#    'display_login': 'islamshalaby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/islamshalaby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33799954?'},
#   'repo': {'id': 337660726,
#    'name': 'islamshalaby/gulf',
#    'url': 'https://api.github.com/repos/islamshalaby/gulf'},
#   'payload': {'push_id': 9027667783,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '095f5be59646f03412eff48007e79b9ed83f551c',
#    'before': '87db2079e58a974874e928ff00efbae4dab7a85f',
#    'commits': [{'sha': '095f5be59646f03412eff48007e79b9ed83f551c',
#      'author': {'email': 'islamshalby510@gmail.com', 'name': 'Islam Shalaby'},
#      'message': 'edits 7/2/2022 v1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/islamshalaby/gulf/commits/095f5be59646f03412eff48007e79b9ed83f551c'}]},
#   'public': True,
#   'created_at': '2022-02-07T07:50:35Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

# API範例1
r = requests.get('https://cat-fact.herokuapp.com/facts')
r.json()
# Out:
# [{'status': {'verified': True, 'feedback': '', 'sentCount': 1},
#   '_id': '5887e1d85c873e0011036889',
#   'user': '5a9ac18c7478810ea6c06381',
#   'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-09-03T16:39:39.578Z',
#   'type': 'cat',
#   'createdAt': '2018-01-15T21:20:00.003Z',
#   'deleted': False,
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '588e746706ac2b00110e59ff',
#   'user': '588e6e8806ac2b00110e59c3',
#   'text': 'Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-26T20:20:02.359Z',
#   'type': 'cat',
#   'createdAt': '2018-01-14T21:20:02.750Z',
#   'deleted': False,
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58923f2fc3878c0011784c79',
#   'user': '5887e9f65c873e001103688d',
#   'text': "I don't know anything about cats.",
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-02-25T21:20:03.060Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '5894af975cdc7400113ef7f9',
#   'user': '5a9ac18c7478810ea6c06381',
#   'text': 'The technical term for a cat’s hairball is a bezoar.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-11-25T21:20:03.895Z',
#   'type': 'cat',
#   'createdAt': '2018-02-27T21:20:02.854Z',
#   'deleted': False,
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e007cc0aac31001185ecf5',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-01T21:20:02.713Z',
#   'deleted': False,
#   'used': False}]

# %%
# API範例2
r = requests.get("https://opendata.epa.gov.tw/ws/Data/AQI/?$format=json", verify=False)
list_of_dicts = r.json()

print(type(r))
print(type(list_of_dicts))  #為list，其中每個元素都自成一個dict
for i in list_of_dicts:
    print(i["County"], i["SiteName"], i["PM2.5"])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.epa.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <class 'requests.models.Response'>
# <class 'list'>
# 屏東縣 屏東(枋寮) 23
# 臺南市 臺南(學甲) 23
# 新北市 新北(樹林) 22
# 屏東縣 屏東(琉球) 4
# 臺南市 臺南(麻豆) 16
# 高雄市 高雄(湖內) 23
# 彰化縣 大城 20
# 新北市 富貴角 19
# 雲林縣 麥寮 25
# 臺東縣 關山 5
# 澎湖縣 馬公 17
# 金門縣 金門 33
# 連江縣 馬祖 9
# 南投縣 埔里 14
# 高雄市 復興 33
# 新北市 永和 26
# 南投縣 竹山 24
# 桃園市 中壢 16
# 新北市 三重 32
# 宜蘭縣 冬山 5
# 宜蘭縣 宜蘭 8
# 臺北市 陽明 6
# 花蓮縣 花蓮 10
# 臺東縣 臺東 4
# 屏東縣 恆春 11
# 屏東縣 潮州 31
# 屏東縣 屏東 31
# 高雄市 小港
# 高雄市 前鎮 30
# 高雄市 前金 28
# 高雄市 左營 37
# 高雄市 楠梓 43
# 高雄市 林園 26
# 高雄市 大寮 32
# 高雄市 鳳山
# 高雄市 仁武 41
# 高雄市 橋頭 47
# 高雄市 美濃 21
# 臺南市 臺南 20
# 臺南市 安南 19
# 臺南市 善化 25
# 臺南市 新營 21
# 嘉義市 嘉義 31
# 雲林縣 臺西 18
# 嘉義縣 朴子 16
# 嘉義縣 新港 29
# 雲林縣 崙背 21
# 雲林縣 斗六 30
# 南投縣 南投 28
# 彰化縣 二林 28
# 彰化縣 線西 20
# 彰化縣 彰化 24
# 臺中市 西屯 25
# 臺中市 忠明 28
# 臺中市 大里 27
# 臺中市 沙鹿 18
# 臺中市 豐原 21
# 苗栗縣 三義 16
# 苗栗縣 苗栗 15
# 苗栗縣 頭份 16
# 新竹市 新竹 12
# 新竹縣 竹東 12
# 新竹縣 湖口 16
# 桃園市 龍潭 19
# 桃園市 平鎮 15
# 桃園市 觀音 16
# 桃園市 大園 14
# 桃園市 桃園 25
# 臺北市 大同 32
# 臺北市 松山 15
# 臺北市 古亭 25
# 臺北市 萬華 30
# 臺北市 中山 34
# 臺北市 士林 16
# 新北市 淡水 21
# 新北市 林口 27
# 新北市 菜寮 23
# 新北市 新莊 18
# 新北市 板橋 30
# 新北市 土城 24
# 新北市 新店 15
# 新北市 萬里 4
# 新北市 汐止 4
# 基隆市 基隆 5
