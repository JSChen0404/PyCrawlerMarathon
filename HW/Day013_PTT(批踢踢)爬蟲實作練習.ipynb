# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# <a class="btn" href="/man/NBA/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/NBA/index6503.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646701472.A.FA8.html">[Live] 湖人 @ 馬刺</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E6%B9%96%E4%BA%BA+%40+%E9%A6%AC%E5%88%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646701626.A.3F1.html">[Live] 爵士 @ 獨行俠</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E7%88%B5%E5%A3%AB+%40+%E7%8D%A8%E8%A1%8C%E4%BF%A0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">56</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646701850.A.8CC.html">[新聞] 湖人今拚2個月來首波連勝　Westbrook妻</a>
# </div>
# <div class="meta">
# <div class="author">arod1414</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E6%B9%96%E4%BA%BA%E4%BB%8A%E6%8B%9A2%E5%80%8B%E6%9C%88%E4%BE%86%E9%A6%96%E6%B3%A2%E9%80%A3%E5%8B%9D%E3%80%80Westbrook%E5%A6%BB">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aarod1414">搜尋看板內 arod1414 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">81</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646703801.A.E2B.html">[Live] 勇士 @ 金塊</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E5%8B%87%E5%A3%AB+%40+%E9%87%91%E5%A1%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">94</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646703867.A.694.html">[外絮] Dirk談當年模仿咳嗽事件：有點不尊重人</a>
# </div>
# <div class="meta">
# <div class="author">Wojnarowski</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%A4%96%E7%B5%AE%5D+Dirk%E8%AB%87%E7%95%B6%E5%B9%B4%E6%A8%A1%E4%BB%BF%E5%92%B3%E5%97%BD%E4%BA%8B%E4%BB%B6%EF%BC%9A%E6%9C%89%E9%BB%9E%E4%B8%8D%E5%B0%8A%E9%87%8D%E4%BA%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AWojnarowski">搜尋看板內 Wojnarowski 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">43</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646706920.A.207.html">[BOX ] Bulls 106:121 Sixers 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Bulls+106%3A121+Sixers+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
#
# 				(本文已被刪除) [Rambo]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">42</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646707141.A.80E.html">[情報] 公牛對戰東西區前三名0勝14敗</a>
# </div>
# <div class="meta">
# <div class="author">jeff1013</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E5%85%AC%E7%89%9B%E5%B0%8D%E6%88%B0%E6%9D%B1%E8%A5%BF%E5%8D%80%E5%89%8D%E4%B8%89%E5%90%8D0%E5%8B%9D14%E6%95%97">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ajeff1013">搜尋看板內 jeff1013 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">15</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646708018.A.278.html">[BOX ] Hawks 110:113 Pistons 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Hawks+110%3A113+Pistons+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">16</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646708313.A.C2C.html">[BOX ] Rockets 106:123 Heat 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Rockets+106%3A123+Heat+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646708369.A.B48.html">[BOX ] Rockets 106:123 Heat 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Rockets+106%3A123+Heat+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646708633.A.3C7.html">[Live] 尼克 @ 國王</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E5%B0%BC%E5%85%8B+%40+%E5%9C%8B%E7%8E%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1637555315.A.C34.html">[公告] 板規v9.0</a>
# </div>
# <div class="meta">
# <div class="author">pneumo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8Fv9.0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Apneumo">搜尋看板內 pneumo 的文章</a></div>
# </div>
# </div>
# <div class="date">11/22</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">21</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1645629309.A.CEA.html">[情報] SEASON Schedule March 21–22</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+SEASON+Schedule+March+21%E2%80%9322">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">10</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1646632190.A.366.html">[情報] NBA Standings (Mar. 07, 2022)</a>
# </div>
# <div class="meta">
# <div class="author">guardyo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Mar.+07%2C+2022%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/07</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
list1 = []
for d in soup.find_all(class_="r-ent"):
    try:
        a=d.find(class_='date').text    
        b=d.find('a').text        
        c=d.find(class_='author').text
        ele = (a,b,c)
        list1.append(ele)
    except:
        continue
list1[-4]
# Out:
# (' 3/08', '[Live] 尼克 @ 國王', 'laptic')

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
for d in soup.find_all(class_="r-ent"):
    try:
        print('作者:', d.find(class_='author').text,'; 標題:', d.find('a').text,'; 時間:', d.find(class_='date').text)        
#         print('標題: ', d.find('a').text)
#         print('時間: ', d.find(class_='date').text)
    except:
        continue
# Out:
# 作者: laptic ; 標題: [Live] 湖人 @ 馬刺 ; 時間:  3/08
# 作者: laptic ; 標題: [Live] 爵士 @ 獨行俠 ; 時間:  3/08
# 作者: arod1414 ; 標題: [新聞] 湖人今拚2個月來首波連勝　Westbrook妻 ; 時間:  3/08
# 作者: laptic ; 標題: [Live] 勇士 @ 金塊 ; 時間:  3/08
# 作者: Wojnarowski ; 標題: [外絮] Dirk談當年模仿咳嗽事件：有點不尊重人 ; 時間:  3/08
# 作者: Rambo ; 標題: [BOX ] Bulls 106:121 Sixers 數據 ; 時間:  3/08
# 作者: jeff1013 ; 標題: [情報] 公牛對戰東西區前三名0勝14敗 ; 時間:  3/08
# 作者: Rambo ; 標題: [BOX ] Hawks 110:113 Pistons 數據 ; 時間:  3/08
# 作者: Rambo ; 標題: [BOX ] Rockets 106:123 Heat 數據 ; 時間:  3/08
# 作者: Rambo ; 標題: [BOX ] Rockets 106:123 Heat 數據 ; 時間:  3/08
# 作者: laptic ; 標題: [Live] 尼克 @ 國王 ; 時間:  3/08
# 作者: pneumo ; 標題: [公告] 板規v9.0 ; 時間: 11/22
# 作者: laptic ; 標題: [情報] SEASON Schedule March 21–22 ; 時間:  2/23
# 作者: guardyo ; 標題: [情報] NBA Standings (Mar. 07, 2022) ; 時間:  3/07

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
