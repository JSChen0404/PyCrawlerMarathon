# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例：
#
# 1. 取出今天所有的新聞
# 2. 取出現在時間兩小時內的新聞
# 3. 根據範例，取出三天前下午三點到五點的新聞

# %% [markdown]
# ## 1. 取出今天所有的新聞

# %%
# !pip install selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path=r'C:\Users\user\Dropbox\23 - Python\Program\chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")

# 每個兩秒鐘自動往下滑

import time
for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 10000);")
    
# 取得資料，丟到 BeautifulSoup 解析

html_source = browser.page_source
soup = BeautifulSoup(html_source, "html.parser")

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('a')[-1].text)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8100/939783628.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=r'C:\Users\user\Dropbox\23 - Python\Program\chromedriver')
# 2022/03/28 22:12 連6天搭北捷！北市曝2大張確診足跡　誠品生活站前店、京站威秀影城上榜
# 2022/03/28 22:06 志信去年獲利主要來自業外與子公司　擬配發現金股利與股票股利各1元
# 2022/03/28 22:05 紫爆大雨夜臨！下一波水彈濕冷凍骨5天　急寒14°C直逼「冷氣團」
# 2022/03/28 22:04 快訊／三重確診案延燒！北市曝2確診足跡　曾到新光三越、內湖好市多
# 2022/03/28 22:04 德國內政部：展示字母「Z」可能是犯罪　讚揚俄羅斯侵略將被起訴
# 2022/03/28 22:03 工商領袖代表齊聚新北產發會　5大面向擘劃黃金10年榮景
# 2022/03/28 22:02 日本成人年齡下調至18歲　律師憂心易淪為詐騙目標
# 2022/03/28 22:01 與蔣萬安推出聯合政見？　侯友宜：可一起拚讓雙北更好
# 2022/03/28 21:59 外資評估半導體恐面臨砍單　黃崇仁批：僅看單一產品為「落後思想」
# 2022/03/28 21:53 台中2歲女童遭「背帶纏頸」插管搶救！警依過失傷害偵辦保姆
# 2022/03/28 21:47 基隆第二分局長確診！指揮中心證實：病毒量高Ct值13
# 2022/03/28 21:45 福來喜雙安開轟！岳政華猛敲3安也有全壘打演出
# 2022/03/28 21:41 快訊／淡水分局偵查隊林口辦案　1警中彈送醫
# 2022/03/28 21:40 速霸陸電動休旅車「確定引進台灣市場」！RAV4兄弟車將同台競爭
# 2022/03/28 21:38 阿金「屎意襲身」待轉格內無情解放　姐停車撿屎尷尬：臉好綠
# ...

# %% [markdown]
# ## 2. 取出現在時間兩小時內的新聞

# %%
browser = webdriver.Chrome(executable_path=r'C:\Users\user\Dropbox\23 - Python\Program\chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")

# 每個兩秒鐘自動往下滑
for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 10000);")
    
# 取得資料，丟到 BeautifulSoup 解析
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html.parser")

for d in soup.find(class_="part_list_2").find_all('h3'):
#     date = datetime.datetime.strptime(d.find(class_="date").text, "%Y/%m/%d %H:%M")
    if d.find(class_="date").text[11:13] in ('22' '23'):    
        print(d.find(class_="date").text, d.find_all('a')[-1].text)
        
# 關閉瀏覽器
browser.quit();
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8100/2165723719.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=r'C:\Users\user\Dropbox\23 - Python\Program\chromedriver')
# 2022/03/28 22:12 連6天搭北捷！北市曝2大張確診足跡　誠品生活站前店、京站威秀影城上榜
# 2022/03/28 22:06 志信去年獲利主要來自業外與子公司　擬配發現金股利與股票股利各1元
# 2022/03/28 22:05 紫爆大雨夜臨！下一波水彈濕冷凍骨5天　急寒14°C直逼「冷氣團」
# 2022/03/28 22:04 快訊／三重確診案延燒！北市曝2確診足跡　曾到新光三越、內湖好市多
# 2022/03/28 22:04 德國內政部：展示字母「Z」可能是犯罪　讚揚俄羅斯侵略將被起訴
# 2022/03/28 22:03 工商領袖代表齊聚新北產發會　5大面向擘劃黃金10年榮景
# 2022/03/28 22:02 日本成人年齡下調至18歲　律師憂心易淪為詐騙目標
# 2022/03/28 22:01 與蔣萬安推出聯合政見？　侯友宜：可一起拚讓雙北更好

# %% [markdown]
# ## 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
browser = webdriver.Chrome(executable_path=r'C:\Users\user\Dropbox\23 - Python\Program\chromedriver')

browser.get(r"https://www.ettoday.net/news/news-list-2022-3-25-0.htm")

# 每個兩秒鐘自動往下滑
for i in range(16):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 100000);")
    
# 取得資料，丟到 BeautifulSoup 解析
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html.parser")

for d in soup.find(class_="part_list_2").find_all('h3'):
    t = d.find(class_="date").text
    if (t[:10] == "2022/03/25") & (t[11:13] in ('15' '16' '17')):
        print(d.find(class_="date").text, d.find_all('a')[-1].text)
        
# 關閉瀏覽器
browser.quit();
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8100/1432192156.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=r'C:\Users\user\Dropbox\23 - Python\Program\chromedriver')
# 2022/03/25 17:59 台揚董座顏信介逝世　接任人選待董事會重新推舉後公布
# 2022/03/25 17:59 理財周刊／少了俄羅斯石油　特斯拉笑了
# 2022/03/25 17:58 卓冠廷找10位跨派系大咖力挺　被形容像「啄木鳥」很會揭弊
# 2022/03/25 17:57 《華燈3》超正酒店妹！網起底「文大楊冪」IG仙照　還是手搖飲闆娘
# 2022/03/25 17:55 以為有「蜘蛛人」幫自己！HBL年度MVP陳將双：看見他會哭出來
# 2022/03/25 17:55 財運找上門的辦公室「17個必知風水」一次看
# 2022/03/25 17:55 李根大尉爆躲波蘭「忙拍戰爭片」　團隊氣炸了！狂列6點喊告
# 2022/03/25 17:55 反指標？看空半導體下修台積電目標價　外資反手連3天買進
# 2022/03/25 17:54 標哥怒了！大甲鎮瀾兒童家園被駭　300捐款人狂接詐騙電話
# 2022/03/25 17:53 民進黨北市議員初選32人搶26席提名　老將張茂楠交棒女兒參選
# 2022/03/25 17:53 慧洋去年EPS11.05元　將配發現金股利5.5元為歷年新高　殖利率6.49%
# 2022/03/25 17:53 點名周典論、林恊松！莊瑞雄秀3手板　控周春米讓國民黨介入初選
# 2022/03/25 17:53 原鄉奉獻30年！「比立」2神父今獲身分證　成為正港台灣人
# 2022/03/25 17:53 習近平「破例」通話尹錫悅25分鐘！　承諾儘速推動中韓領導人峰會
# 2022/03/25 17:52 殺到快對折！日本直送「北海道鍋物組」　花咲蟹、根昆布高湯超鮮甜
# ...
